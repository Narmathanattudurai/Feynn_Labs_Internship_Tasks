# %%
import pandas as pd

# %%
mcdonalds=pd.read_csv('mcdonalds.csv')

# %%
mcdonalds.head()
# Out:
#   yummy convenient spicy fattening greasy fast cheap tasty expensive healthy  \
# 0    No        Yes    No       Yes     No  Yes   Yes    No       Yes      No
# 1   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes       Yes      No
# 2    No        Yes   Yes       Yes    Yes  Yes    No   Yes       Yes     Yes
# 3   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No      No
# 4    No        Yes    No       Yes    Yes  Yes   Yes    No        No     Yes
#
#   disgusting Like  Age      VisitFrequency  Gender
# 0         No   -3   61  Every three months  Female
# 1         No   +2   51  Every three months  Female
# 2         No   +1   62  Every three months  Female
# 3        Yes   +4   69         Once a week  Female
# 4         No   +2   49        Once a month    Male

# %%
mcdonalds.shape
# Out:
# (1453, 15)

# %%
mcdonalds['Gender'].astype('category')
# Out:
# 0       Female
# 1       Female
# 2       Female
# 3       Female
# 4         Male
#          ...
# 1448      Male
# 1449    Female
# 1450    Female
# 1451      Male
# 1452      Male
# Name: Gender, Length: 1453, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
mcdonalds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yummy           1453 non-null   object
#  1   convenient      1453 non-null   object
#  2   spicy           1453 non-null   object
#  3   fattening       1453 non-null   object
#  4   greasy          1453 non-null   object
#  5   fast            1453 non-null   object
#  6   cheap           1453 non-null   object
#  7   tasty           1453 non-null   object
#  8   expensive       1453 non-null   object
#  9   healthy         1453 non-null   object
#  10  disgusting      1453 non-null   object
#  11  Like            1453 non-null   object
#  12  Age             1453 non-null   int64
#  13  VisitFrequency  1453 non-null   object
#  14  Gender          1453 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 170.4+ KB

# %%
mcdonalds.isnull()
# Out:
#       yummy  convenient  spicy  fattening  greasy   fast  cheap  tasty  \
# 0     False       False  False      False   False  False  False  False
# 1     False       False  False      False   False  False  False  False
# 2     False       False  False      False   False  False  False  False
# 3     False       False  False      False   False  False  False  False
# 4     False       False  False      False   False  False  False  False
# ...     ...         ...    ...        ...     ...    ...    ...    ...
# 1448  False       False  False      False   False  False  False  False
# 1449  False       False  False      False   False  False  False  False
# 1450  False       False  False      False   False  False  False  False
# 1451  False       False  False      False   False  False  False  False
# 1452  False       False  False      False   False  False  False  False
#
#       expensive  healthy  disgusting   Like    Age  VisitFrequency  Gender
# 0         False    False       False  False  False           False   False
# 1         False    False       False  False  False           False   False
# 2         False    False       False  False  False           False   False
# 3         False    False       False  False  False           False   False
# 4         False    False       False  False  False           False   False
# ...         ...      ...         ...    ...    ...             ...     ...
# 1448      False    False       False  False  False           False   False
# 1449      False    False       False  False  False           False   False
# 1450      False    False       False  False  False           False   False
# 1451      False    False       False  False  False           False   False
# 1452      False    False       False  False  False           False   False
#
# [1453 rows x 15 columns]

# %%
mcdonalds.describe()
# Out:
#                Age
# count  1453.000000
# mean     44.604955
# std      14.221178
# min      18.000000
# 25%      33.000000
# 50%      45.000000
# 75%      57.000000
# max      71.000000

# %%
mcdonalds.sample(10)
# Out:
#      yummy convenient spicy fattening greasy fast cheap tasty expensive  \
# 497    Yes        Yes    No       Yes     No  Yes   Yes   Yes        No
# 1420   Yes        Yes    No       Yes     No  Yes   Yes   Yes        No
# 1017    No        Yes    No       Yes    Yes  Yes    No    No       Yes
# 1045   Yes        Yes    No       Yes    Yes  Yes   Yes   Yes        No
# 589     No        Yes    No       Yes     No  Yes   Yes    No        No
# 848     No        Yes    No       Yes    Yes  Yes    No    No       Yes
# 749     No        Yes    No       Yes    Yes  Yes    No   Yes       Yes
# 1234    No        Yes    No       Yes    Yes  Yes    No    No        No
# 1202   Yes        Yes    No       Yes    Yes  Yes    No   Yes       Yes
# 1332   Yes        Yes    No       Yes    Yes  Yes    No   Yes       Yes
#
#      healthy disgusting          Like  Age      VisitFrequency  Gender
# 497       No         No  I hate it!-5   64        Once a month  Female
# 1420      No         No            +3   53        Once a month  Female
# 1017      No        Yes  I hate it!-5   50               Never  Female
# 1045      No         No  I love it!+5   18         Once a week    Male
# 589       No        Yes  I hate it!-5   34         Once a year    Male
# 848       No        Yes  I hate it!-5   45               Never    Male
# 749       No        Yes             0   18  Every three months    Male
# 1234      No         No  I hate it!-5   61  Every three months  Female
# 1202      No         No            +3   24        Once a month  Female
# 1332      No         No            +4   40         Once a week  Female

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
mcdonalds.hist(column='Age')
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
age_array=mcdonalds[['Age']].to_numpy()

# %%
plt.hist(age_array, bins=5, rwidth=0.95)
# Out:
# (array([246., 328., 268., 385., 226.]),
#  array([18. , 28.6, 39.2, 49.8, 60.4, 71. ]),
#  <BarContainer object of 5 artists>)

# %%
mcdonalds.groupby(['Like']).sum()
# Out:
#                Age
# Like
# +1            6909
# +2            8131
# +3            9418
# +4            6914
# -1            2631
# -2            2715
# -3            3604
# -4            3635
# 0             8055
# I hate it!-5  7549
# I love it!+5  5250

# %%
mcdonalds.groupby(['Gender']).count()
# Out:
#         yummy  convenient  spicy  fattening  greasy  fast  cheap  tasty  \
# Gender
# Female    788         788    788        788     788   788    788    788
# Male      665         665    665        665     665   665    665    665
#
#         expensive  healthy  disgusting  Like  Age  VisitFrequency
# Gender
# Female        788      788         788   788  788             788
# Male          665      665         665   665  665             665
